# %% [markdown]
# <a href="https://colab.research.google.com/github/Vannod/Simulacion-I/blob/main/Transformada_Inversa%5CP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Método de la transformada inversa
#
# Alumna: Ortiz Diaz Vania Yael

# %% [markdown]
# ## Librerias

# %%
# Importamos las librerias que usaremos para el programa
import numpy as np
import random as rnd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Método

# %%
# Definimos una función para calcular Método de la Transformada Inversa
def TI(landa, n):
  L = - 1 / landa
  lista = []
  for i in range (n):
    U = rnd.uniform(0, 1) # Generamos números aleatorios distribuidos uniformemente de 0 a 1
    X = L * np.log(1 - U) # Aplicamos la transformación inversa
    lista.append(X) # Almacenamos los resulados en una lista
  return lista

Resultados = TI(1.5, 10000)

# %% [markdown]
# # Función de densidad de probabilidad

# %%
landa = 1.5 # Tomamos a 1.5 como valor de lambda
x = np.linspace(0, 10, 100)
fdp = landa * np.exp(-landa * x) # Calcula la Función de densidad de probabilidad para diferentes valores de x

# Grafica de la Función de densidad de probabilidad
plt.plot(x, fdp)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Función de densidad de probabilidad')
plt.show()

# %% [markdown]
# ## Función acumulativa

# %%
landa = 1.5 # Tomamos a 1.5 como valor de lambda
x = np.linspace(0, 10, 100)
fda = 1 - np.exp(-landa * x)  # Calcula la Función Acumulativa para diferentes valores de x

# Grafica de la Función Acumulativa
plt.plot(x, fda)
plt.xlabel('x')
plt.ylabel('F(x)')
plt.title('Función Acumulativa')
plt.show()

# %% [markdown]
# ## Histograma de la muestra

# %%
# Usamos la mustra resultante de nuestro método
plt.hist(Resultados, bins=50, density=True, color='blue', alpha=0.7)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Histograma de la muestra')

x = np.linspace(0, max(Resultados), 100)
fdp = landa * np.exp(-landa * x)
plt.plot(x, fdp, label='FDP Teórica', color='r')

plt.show()
